# %%
display(dbutils.fs.ls("dbfs:/Workspace/Users/freddyplati@gmail.com/Week 11 PySpark Data Processing/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Workspace/Users/freddyplati@gmail.com/Week 11 PySpark Data Processing/Week11 Assignment.ipynb</td><td>Week11 Assignment.ipynb</td><td>1007</td><td>1762655254020</td></tr><tr><td>dbfs:/Workspace/Users/freddyplati@gmail.com/Week 11 PySpark Data Processing/fhvhv_tripdata_2025-01.parquet</td><td>fhvhv_tripdata_2025-01.parquet</td><td>491076642</td><td>1762655026826</td></tr><tr><td>dbfs:/Workspace/Users/freddyplati@gmail.com/Week 11 PySpark Data Processing/fhvhv_tripdata_2025-02.parquet</td><td>fhvhv_tripdata_2025-02.parquet</td><td>461632254</td><td>1762655024958</td></tr><tr><td>dbfs:/Workspace/Users/freddyplati@gmail.com/Week 11 PySpark Data Processing/fhvhv_tripdata_2025-03.parquet</td><td>fhvhv_tripdata_2025-03.parquet</td><td>501783767</td><td>1762655027681</td></tr></tbody></table></div>

# %%
# %sql
CREATE CATALOG IF NOT EXISTS main;
CREATE SCHEMA  IF NOT EXISTS main.default;
CREATE VOLUME  IF NOT EXISTS main.default.nyc_fhvhv;

# %%
# Source = your Workspace folder that listed successfully
src_base = "dbfs:/Workspace/Users/freddyplati@gmail.com/Week 11 PySpark Data Processing/"
dst_base = "/Volumes/main/default/nyc_fhvhv"

# Make sure destination exists
dbutils.fs.mkdirs(dst_base)

# Copy the three Parquet files into the Volume
for m in ["01","02","03"]:
    src = f"{src_base}fhvhv_tripdata_2025-{m}.parquet"
    dst = f"{dst_base}/fhvhv_tripdata_2025-{m}.parquet"
    # recurse=False because each is a single parquet file (not a folder)
    dbutils.fs.cp(src, dst, recurse=False)

# Verify they are in the Volume
display(dbutils.fs.ls(dst_base))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/main/default/nyc_fhvhv/fhvhv_tripdata_2025-01.parquet</td><td>fhvhv_tripdata_2025-01.parquet</td><td>491076642</td><td>1762655925000</td></tr><tr><td>dbfs:/Volumes/main/default/nyc_fhvhv/fhvhv_tripdata_2025-02.parquet</td><td>fhvhv_tripdata_2025-02.parquet</td><td>461632254</td><td>1762655943000</td></tr><tr><td>dbfs:/Volumes/main/default/nyc_fhvhv/fhvhv_tripdata_2025-03.parquet</td><td>fhvhv_tripdata_2025-03.parquet</td><td>501783767</td><td>1762655959000</td></tr></tbody></table></div>

# %%
from pyspark.sql import functions as F

fhvhv_tr = (fhvhv
  # timestamps are already timestamp_ntz; just reuse
  .withColumn("pickup_ts",  F.col("pickup_datetime"))
  .withColumn("dropoff_ts", F.col("dropoff_datetime"))
  .withColumn("year",  F.year("pickup_ts"))
  .withColumn("month", F.month("pickup_ts"))
  .withColumn("trip_minutes", (F.col("trip_time")/60.0))

  # sanity speed (trip_time is seconds in TLC; adjust if your docs differ)
  .withColumn("speed_mph",
              F.when(F.col("trip_minutes") > 0,
                     F.col("trip_miles")/(F.col("trip_minutes")/60.0)))

  # normalize nulls to 0 for money fields
  .withColumn("fare",              F.coalesce(F.col("base_passenger_fare"), F.lit(0.0)))
  .withColumn("tolls_",            F.coalesce(F.col("tolls"), F.lit(0.0)))
  .withColumn("tips_",             F.coalesce(F.col("tips"), F.lit(0.0)))
  .withColumn("bcf_",              F.coalesce(F.col("bcf"), F.lit(0.0)))  # Black Car Fund
  .withColumn("sales_tax_",        F.coalesce(F.col("sales_tax"), F.lit(0.0)))
  .withColumn("congestion_",       F.coalesce(F.col("congestion_surcharge"), F.lit(0.0)))
  .withColumn("airport_fee_",      F.coalesce(F.col("airport_fee"), F.lit(0.0)))
  .withColumn("cbd_congestion_",   F.coalesce(F.col("cbd_congestion_fee"), F.lit(0.0)))

  # build revenue = fare + surcharges/fees + tips + tolls
  .withColumn("revenue",
              F.col("fare") + F.col("tolls_") + F.col("tips_") + F.col("bcf_")
              + F.col("sales_tax_") + F.col("congestion_") + F.col("airport_fee_")
              + F.col("cbd_congestion_"))

  .withColumn("tip_rate",
              F.when(F.col("fare") > 0, F.col("tips_")/F.col("fare")).otherwise(F.lit(0.0)))

  # early filters (2+)
  .filter(F.col("PULocationID").isNotNull() & F.col("DOLocationID").isNotNull())
  .filter((F.col("trip_miles") > 0) & (F.col("trip_time") > 0))
  .filter((F.col("speed_mph") >= 1) & (F.col("speed_mph") <= 90))

  # column pruning
  .select("pickup_ts","dropoff_ts","year","month","PULocationID","DOLocationID",
          "trip_miles","trip_minutes","speed_mph","fare","tips_","tolls_","revenue",
          "tip_rate","hvfhs_license_num")
  .withColumnRenamed("tips_", "tips")
  .withColumnRenamed("tolls_","tolls")
)

# %%
# KPIs by month
kpi_month = (fhvhv_tr
  .groupBy("year","month")
  .agg(F.count("*").alias("trips"),
       F.avg("speed_mph").alias("avg_speed"),
       F.sum("revenue").alias("revenue_sum"),
       F.avg("tip_rate").alias("avg_tip_rate"))
  .orderBy("year","month"))

kpi_month.show()

# Two SQL queries
fhvhv_tr.createOrReplaceTempView("fhvhv")

sql_a = spark.sql("""
  SELECT year, month,
         COUNT(*) AS trips,
         AVG(speed_mph) AS avg_speed,
         SUM(revenue) AS revenue_sum
  FROM fhvhv
  WHERE speed_mph BETWEEN 1 AND 90
  GROUP BY year, month
  ORDER BY year, month
""")

sql_b = spark.sql("""
  SELECT PULocationID, COUNT(*) AS trips, SUM(revenue) AS revenue_sum
  FROM fhvhv
  WHERE year = 2025 AND month IN (1,2,3)
  GROUP BY PULocationID
  ORDER BY trips DESC
  LIMIT 20
""")
# Out:
# +----+-----+--------+------------------+-------------------+--------------------+
# |year|month|   trips|         avg_speed|        revenue_sum|        avg_tip_rate|
# +----+-----+--------+------------------+-------------------+--------------------+
# |2025|    1|20400288|13.939180662952221|6.264227268287927E8|0.038985726740600884|
# |2025|    2|19334052| 13.69140516314002|6.092364401687396E8| 0.03697393015432927|
# |2025|    3|20531303| 13.80096165959246|7.091356421488773E8| 0.03561225178814893|
# +----+-----+--------+------------------+-------------------+--------------------+

# %%
# %sql
CREATE VOLUME IF NOT EXISTS main.default.nyc_fhvhv_out;

# %%
# %sql
SHOW VOLUMES IN main.default;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody><tr><td>default</td><td>nyc_fhvhv</td></tr><tr><td>default</td><td>nyc_fhvhv_out</td></tr></tbody></table></div>

# %%
out_dir = "/Volumes/main/default/nyc_fhvhv_out"

(fhvhv_tr
 .write.mode("overwrite")
 .partitionBy("year","month")
 .parquet(f"{out_dir}/fhvhv_tr_partitioned"))

(kpi_month.coalesce(1)
 .write.mode("overwrite").parquet(f"{out_dir}/kpi_month"))

(sql_a.write.mode("overwrite").parquet(f"{out_dir}/sql_a"))
(sql_b.write.mode("overwrite").parquet(f"{out_dir}/sql_b"))

# %%
print("\n==== EXPLAIN: kpi_month ====\n")
kpi_month.explain(mode="formatted")

print("\n==== EXPLAIN: sql_a ====\n")
sql_a.explain(mode="formatted")
# Out:
# ==== EXPLAIN: kpi_month ====
#
# == Physical Plan ==
# AdaptiveSparkPlan (16)
# +- == Initial Plan ==
#    ColumnarToRow (15)
#    +- PhotonResultStage (14)
#       +- PhotonSort (13)
#          +- PhotonShuffleExchangeSource (12)
#             +- PhotonShuffleMapStage (11)
#                +- PhotonShuffleExchangeSink (10)
#                   +- PhotonGroupingAgg (9)
#                      +- PhotonShuffleExchangeSource (8)
#                         +- PhotonShuffleMapStage (7)
#                            +- PhotonShuffleExchangeSink (6)
#                               +- PhotonGroupingAgg (5)
#                                  +- PhotonProject (4)
#                                     +- PhotonProject (3)
#                                        +- PhotonProject (2)
#                                           +- PhotonScan parquet  (1)
#
#
# (1) PhotonScan parquet
# Output [13]: [pickup_datetime#11315, PULocationID#11317, DOLocationID#11318, trip_miles#11319, trip_time#11320L, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334]
# DictionaryFilters: [(trip_time#11320L > 0), (trip_miles#11319 > 0.0)]
# Location: InMemoryFileIndex [dbfs:/Volumes/main/default/nyc_fhvhv/fhvhv_tripdata_2025-01.parquet, ... 2 entries]
# ReadSchema: struct<pickup_datetime:timestamp_ntz,PULocationID:int,DOLocationID:int,trip_miles:double,trip_time:bigint,base_passenger_fare:double,tolls:double,bcf:double,sales_tax:double,congestion_surcharge:double,airport_fee:double,tips:double,cbd_congestion_fee:double>
# RequiredDataFilters: [isnotnull(PULocationID#11317), isnotnull(DOLocationID#11318), isnotnull(trip_miles#11319), isnotnull(trip_time#11320L), (trip_miles#11319 > 0.0), (trip_time#11320L > 0), CASE WHEN ((cast(trip_time#11320L as double) / 60.0) > 0.0) THEN ((trip_miles#11319 / ((cast(trip_time#11320L as double) / 60.0) / 60.0)) >= 1.0) END, CASE WHEN ((cast(trip_time#11320L as double) / 60.0) > 0.0) THEN ((trip_miles#11319 / ((cast(trip_time#11320L as double) / 60.0) / 60.0)) <= 90.0) END]
#
# (2) PhotonProject
# Input [13]: [pickup_datetime#11315, PULocationID#11317, DOLocationID#11318, trip_miles#11319, trip_time#11320L, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334]
# Arguments: [trip_miles#11319, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334, year(cast(pickup_datetime#11315 as date)) AS year#11343, month(cast(pickup_datetime#11315 as date)) AS month#11345, (cast(trip_time#11320L as double) / 60.0) AS trip_minutes#11347]
#
# (3) PhotonProject
# Input [12]: [trip_miles#11319, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334, year#11343, month#11345, trip_minutes#11347]
# Arguments: [year#11343, month#11345, CASE WHEN (trip_minutes#11347 > 0.0) THEN (trip_miles#11319 / (trip_minutes#11347 / 60.0)) END AS speed_mph#11349, coalesce(base_passenger_fare#11321, 0.0) AS fare#11351, coalesce(tolls#11322, 0.0) AS tolls_#11353, coalesce(tips#11327, 0.0) AS tips_#11355, coalesce(bcf#11323, 0.0) AS bcf_#11357, coalesce(sales_tax#11324, 0.0) AS sales_tax_#11359, coalesce(congestion_surcharge#11325, 0.0) AS congestion_#11361, coalesce(airport_fee#11326, 0.0) AS airport_fee_#11363, coalesce(cbd_congestion_fee#11334, 0.0) AS cbd_congestion_#11365]
#
# (4) PhotonProject
# Input [11]: [year#11343, month#11345, speed_mph#11349, fare#11351, tolls_#11353, tips_#11355, bcf_#11357, sales_tax_#11359, congestion_#11361, airport_fee_#11363, cbd_congestion_#11365]
# Arguments: [year#11343, month#11345, speed_mph#11349, (((((((fare#11351 + tolls_#11353) + tips_#11355) + bcf_#11357) + sales_tax_#11359) + congestion_#11361) + airport_fee_#11363) + cbd_congestion_#11365) AS revenue#11367, CASE WHEN (fare#11351 > 0.0) THEN (tips_#11355 / fare#11351) ELSE 0.0 END AS tip_rate#11369]
#
# (5) PhotonGroupingAgg
# Input [5]: [year#11343, month#11345, speed_mph#11349, revenue#11367, tip_rate#11369]
# Arguments: [year#11343, month#11345], [partial_count(1) AS count#11784L, partial_avg(speed_mph#11349) AS (sum#11787, count#11788L), partial_sum(revenue#11367) AS sum#11790, partial_avg(tip_rate#11369) AS (sum#11793, count#11794L)], [count#11783L, sum#11785, count#11786L, sum#11789, sum#11791, count#11792L], [year#11343, month#11345, count#11784L, sum#11787, count#11788L, sum#11790, sum#11793, count#11794L], false
#
# (6) PhotonShuffleExchangeSink
# Input [8]: [year#11343, month#11345, count#11784L, sum#11787, count#11788L, sum#11790, sum#11793, count#11794L]
# Arguments: hashpartitioning(year#11343, month#11345, 200)
#
# (7) PhotonShuffleMapStage
# Input [8]: [year#11343, month#11345, count#11784L, sum#11787, count#11788L, sum#11790, sum#11793, count#11794L]
# Arguments: ENSURE_REQUIREMENTS, [id=#8933]
#
# (8) PhotonShuffleExchangeSource
# Input [8]: [year#11343, month#11345, count#11784L, sum#11787, count#11788L, sum#11790, sum#11793, count#11794L]
#
# (9) PhotonGroupingAgg
# Input [8]: [year#11343, month#11345, count#11784L, sum#11787, count#11788L, sum#11790, sum#11793, count#11794L]
# Arguments: [year#11343, month#11345], [finalmerge_count(merge count#11784L) AS count(1)#11779L, finalmerge_avg(merge sum#11787, count#11788L) AS avg(speed_mph)#11780, finalmerge_sum(merge sum#11790) AS sum(revenue)#11781, finalmerge_avg(merge sum#11793, count#11794L) AS avg(tip_rate)#11782], [count(1)#11779L, avg(speed_mph)#11780, sum(revenue)#11781, avg(tip_rate)#11782], [year#11343, month#11345, count(1)#11779L AS trips#11508L, avg(speed_mph)#11780 AS avg_speed#11509, sum(revenue)#11781 AS revenue_sum#11510, avg(tip_rate)#11782 AS avg_tip_rate#11511], true
#
# (10) PhotonShuffleExchangeSink
# Input [6]: [year#11343, month#11345, trips#11508L, avg_speed#11509, revenue_sum#11510, avg_tip_rate#11511]
# Arguments: rangepartitioning(year#11343 ASC NULLS FIRST, month#11345 ASC NULLS FIRST, 200)
#
# (11) PhotonShuffleMapStage
# Input [6]: [year#11343, month#11345, trips#11508L, avg_speed#11509, revenue_sum#11510, avg_tip_rate#11511]
# Arguments: ENSURE_REQUIREMENTS, [id=#8939]
#
# (12) PhotonShuffleExchangeSource
# Input [6]: [year#11343, month#11345, trips#11508L, avg_speed#11509, revenue_sum#11510, avg_tip_rate#11511]
#
# (13) PhotonSort
# Input [6]: [year#11343, month#11345, trips#11508L, avg_speed#11509, revenue_sum#11510, avg_tip_rate#11511]
# Arguments: [year#11343 ASC NULLS FIRST, month#11345 ASC NULLS FIRST]
#
# (14) PhotonResultStage
# Input [6]: [year#11343, month#11345, trips#11508L, avg_speed#11509, revenue_sum#11510, avg_tip_rate#11511]
#
# (15) ColumnarToRow
# Input [6]: [year#11343, month#11345, trips#11508L, avg_speed#11509, revenue_sum#11510, avg_tip_rate#11511]
#
# (16) AdaptiveSparkPlan
# Output [6]: [year#11343, month#11345, trips#11508L, avg_speed#11509, revenue_sum#11510, avg_tip_rate#11511]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
#
# ==== EXPLAIN: sql_a ====
#
# == Physical Plan ==
# AdaptiveSparkPlan (15)
# +- == Initial Plan ==
#    ColumnarToRow (14)
#    +- PhotonResultStage (13)
#       +- PhotonSort (12)
#          +- PhotonShuffleExchangeSource (11)
#             +- PhotonShuffleMapStage (10)
#                +- PhotonShuffleExchangeSink (9)
#                   +- PhotonGroupingAgg (8)
#                      +- PhotonShuffleExchangeSource (7)
#                         +- PhotonShuffleMapStage (6)
#                            +- PhotonShuffleExchangeSink (5)
#                               +- PhotonGroupingAgg (4)
#                                  +- PhotonProject (3)
#                                     +- PhotonProject (2)
#                                        +- PhotonScan parquet  (1)
#
#
# (1) PhotonScan parquet
# Output [13]: [pickup_datetime#11315, PULocationID#11317, DOLocationID#11318, trip_miles#11319, trip_time#11320L, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334]
# DictionaryFilters: [(trip_time#11320L > 0), (trip_miles#11319 > 0.0)]
# Location: InMemoryFileIndex [dbfs:/Volumes/main/default/nyc_fhvhv/fhvhv_tripdata_2025-01.parquet, ... 2 entries]
# ReadSchema: struct<pickup_datetime:timestamp_ntz,PULocationID:int,DOLocationID:int,trip_miles:double,trip_time:bigint,base_passenger_fare:double,tolls:double,bcf:double,sales_tax:double,congestion_surcharge:double,airport_fee:double,tips:double,cbd_congestion_fee:double>
# RequiredDataFilters: [isnotnull(PULocationID#11317), isnotnull(DOLocationID#11318), isnotnull(trip_miles#11319), isnotnull(trip_time#11320L), (trip_miles#11319 > 0.0), (trip_time#11320L > 0), CASE WHEN ((cast(trip_time#11320L as double) / 60.0) > 0.0) THEN ((trip_miles#11319 / ((cast(trip_time#11320L as double) / 60.0) / 60.0)) >= 1.0) END, CASE WHEN ((cast(trip_time#11320L as double) / 60.0) > 0.0) THEN ((trip_miles#11319 / ((cast(trip_time#11320L as double) / 60.0) / 60.0)) <= 90.0) END]
#
# (2) PhotonProject
# Input [13]: [pickup_datetime#11315, PULocationID#11317, DOLocationID#11318, trip_miles#11319, trip_time#11320L, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334]
# Arguments: [trip_miles#11319, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334, year(cast(pickup_datetime#11315 as date)) AS year#11343, month(cast(pickup_datetime#11315 as date)) AS month#11345, (cast(trip_time#11320L as double) / 60.0) AS trip_minutes#11347]
#
# (3) PhotonProject
# Input [12]: [trip_miles#11319, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334, year#11343, month#11345, trip_minutes#11347]
# Arguments: [year#11343, month#11345, CASE WHEN (trip_minutes#11347 > 0.0) THEN (trip_miles#11319 / (trip_minutes#11347 / 60.0)) END AS speed_mph#11349, (((((((coalesce(base_passenger_fare#11321, 0.0) + coalesce(tolls#11322, 0.0)) + coalesce(tips#11327, 0.0)) + coalesce(bcf#11323, 0.0)) + coalesce(sales_tax#11324, 0.0)) + coalesce(congestion_surcharge#11325, 0.0)) + coalesce(airport_fee#11326, 0.0)) + coalesce(cbd_congestion_fee#11334, 0.0)) AS revenue#11367]
#
# (4) PhotonGroupingAgg
# Input [4]: [year#11343, month#11345, speed_mph#11349, revenue#11367]
# Arguments: [year#11343, month#11345], [partial_count(1) AS count#11871L, partial_avg(speed_mph#11349) AS (sum#11874, count#11875L), partial_sum(revenue#11367) AS sum#11877], [count#11870L, sum#11872, count#11873L, sum#11876], [year#11343, month#11345, count#11871L, sum#11874, count#11875L, sum#11877], false
#
# (5) PhotonShuffleExchangeSink
# Input [6]: [year#11343, month#11345, count#11871L, sum#11874, count#11875L, sum#11877]
# Arguments: hashpartitioning(year#11343, month#11345, 200)
#
# (6) PhotonShuffleMapStage
# Input [6]: [year#11343, month#11345, count#11871L, sum#11874, count#11875L, sum#11877]
# Arguments: ENSURE_REQUIREMENTS, [id=#9116]
#
# (7) PhotonShuffleExchangeSource
# Input [6]: [year#11343, month#11345, count#11871L, sum#11874, count#11875L, sum#11877]
#
# (8) PhotonGroupingAgg
# Input [6]: [year#11343, month#11345, count#11871L, sum#11874, count#11875L, sum#11877]
# Arguments: [year#11343, month#11345], [finalmerge_count(merge count#11871L) AS count(1)#11867L, finalmerge_avg(merge sum#11874, count#11875L) AS avg(speed_mph)#11868, finalmerge_sum(merge sum#11877) AS sum(revenue)#11869], [count(1)#11867L, avg(speed_mph)#11868, sum(revenue)#11869], [year#11343, month#11345, count(1)#11867L AS trips#11517L, avg(speed_mph)#11868 AS avg_speed#11518, sum(revenue)#11869 AS revenue_sum#11519], true
#
# (9) PhotonShuffleExchangeSink
# Input [5]: [year#11343, month#11345, trips#11517L, avg_speed#11518, revenue_sum#11519]
# Arguments: rangepartitioning(year#11343 ASC NULLS FIRST, month#11345 ASC NULLS FIRST, 200)
#
# (10) PhotonShuffleMapStage
# Input [5]: [year#11343, month#11345, trips#11517L, avg_speed#11518, revenue_sum#11519]
# Arguments: ENSURE_REQUIREMENTS, [id=#9122]
#
# (11) PhotonShuffleExchangeSource
# Input [5]: [year#11343, month#11345, trips#11517L, avg_speed#11518, revenue_sum#11519]
#
# (12) PhotonSort
# Input [5]: [year#11343, month#11345, trips#11517L, avg_speed#11518, revenue_sum#11519]
# Arguments: [year#11343 ASC NULLS FIRST, month#11345 ASC NULLS FIRST]
#
# (13) PhotonResultStage
# Input [5]: [year#11343, month#11345, trips#11517L, avg_speed#11518, revenue_sum#11519]
#
# (14) ColumnarToRow
# Input [5]: [year#11343, month#11345, trips#11517L, avg_speed#11518, revenue_sum#11519]
#
# (15) AdaptiveSparkPlan
# Output [5]: [year#11343, month#11345, trips#11517L, avg_speed#11518, revenue_sum#11519]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
src_df_path = "/Volumes/main/default/nyc_fhvhv"
fhvhv = spark.read.parquet(f"{src_df_path}/fhvhv_tripdata_2025-*.parquet")

# sanity checks
fhvhv.printSchema()
display(fhvhv.limit(5))
# Out:
# root
#  |-- hvfhs_license_num: string (nullable = true)
#  |-- dispatching_base_num: string (nullable = true)
#  |-- originating_base_num: string (nullable = true)
#  |-- request_datetime: timestamp_ntz (nullable = true)
#  |-- on_scene_datetime: timestamp_ntz (nullable = true)
#  |-- pickup_datetime: timestamp_ntz (nullable = true)
#  |-- dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- trip_miles: double (nullable = true)
#  |-- trip_time: long (nullable = true)
#  |-- base_passenger_fare: double (nullable = true)
#  |-- tolls: double (nullable = true)
#  |-- bcf: double (nullable = true)
#  |-- sales_tax: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- airport_fee: double (nullable = true)
#  |-- tips: double (nullable = true)
#  |-- driver_pay: double (nullable = true)
#  |-- shared_request_flag: string (nullable = true)
#  |-- shared_match_flag: string (nullable = true)
#  |-- access_a_ride_flag: string (nullable = true)
#  |-- wav_request_flag: string (nullable = true)
#  |-- wav_match_flag: string (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hvfhs_license_num</th><th>dispatching_base_num</th><th>originating_base_num</th><th>request_datetime</th><th>on_scene_datetime</th><th>pickup_datetime</th><th>dropoff_datetime</th><th>PULocationID</th><th>DOLocationID</th><th>trip_miles</th><th>trip_time</th><th>base_passenger_fare</th><th>tolls</th><th>bcf</th><th>sales_tax</th><th>congestion_surcharge</th><th>airport_fee</th><th>tips</th><th>driver_pay</th><th>shared_request_flag</th><th>shared_match_flag</th><th>access_a_ride_flag</th><th>wav_request_flag</th><th>wav_match_flag</th><th>cbd_congestion_fee</th></tr></thead><tbody><tr><td>HV0003</td><td>B03404</td><td>B03404</td><td>2025-01-01T00:28:07.000</td><td>2025-01-01T00:31:17.000</td><td>2025-01-01T00:33:25.000</td><td>2025-01-01T00:54:24.000</td><td>148</td><td>211</td><td>1.32</td><td>1259</td><td>18.21</td><td>0.0</td><td>0.46</td><td>1.5</td><td>2.75</td><td>0.0</td><td>0.0</td><td>15.71</td><td>N</td><td>N</td><td>N</td><td>N</td><td>N</td><td>0.0</td></tr><tr><td>HV0005</td><td>B03406</td><td>null</td><td>2025-01-01T00:18:33.000</td><td>null</td><td>2025-01-01T00:29:49.000</td><td>2025-01-01T00:41:52.000</td><td>127</td><td>244</td><td>3.313</td><td>723</td><td>16.97</td><td>0.0</td><td>0.47</td><td>1.51</td><td>0.0</td><td>0.0</td><td>0.0</td><td>23.57</td><td>N</td><td>N</td><td>N</td><td>N</td><td>N</td><td>0.0</td></tr><tr><td>HV0003</td><td>B03404</td><td>B03404</td><td>2025-01-01T00:28:22.000</td><td>2025-01-01T00:31:52.000</td><td>2025-01-01T00:32:39.000</td><td>2025-01-01T01:20:33.000</td><td>132</td><td>181</td><td>13.43</td><td>2874</td><td>40.36</td><td>0.0</td><td>1.18</td><td>3.8</td><td>0.0</td><td>2.5</td><td>0.0</td><td>47.75</td><td>N</td><td>N</td><td>N</td><td>N</td><td>N</td><td>0.0</td></tr><tr><td>HV0003</td><td>B03404</td><td>B03404</td><td>2025-01-01T00:27:13.000</td><td>2025-01-01T00:33:58.000</td><td>2025-01-01T00:34:55.000</td><td>2025-01-01T00:39:19.000</td><td>76</td><td>76</td><td>0.82</td><td>264</td><td>12.24</td><td>0.0</td><td>0.34</td><td>1.08</td><td>0.0</td><td>0.0</td><td>0.0</td><td>12.2</td><td>N</td><td>N</td><td>N</td><td>N</td><td>N</td><td>0.0</td></tr><tr><td>HV0003</td><td>B03404</td><td>B03404</td><td>2025-01-01T00:33:29.000</td><td>2025-01-01T00:45:46.000</td><td>2025-01-01T00:46:19.000</td><td>2025-01-01T00:53:56.000</td><td>76</td><td>76</td><td>1.61</td><td>457</td><td>19.76</td><td>0.0</td><td>0.54</td><td>1.76</td><td>0.0</td><td>0.0</td><td>0.0</td><td>17.67</td><td>N</td><td>N</td><td>N</td><td>N</td><td>N</td><td>0.0</td></tr></tbody></table></div>

# %%
# If already uploaded alongside notebook:
zone_src = "dbfs:/Workspace/Users/freddyplati@gmail.com/Week 11 PySpark Data Processing/taxi_zone_lookup.csv"
zone_dst_dir = "/Volumes/main/default/nyc_fhvhv_out/lookup"
dbutils.fs.mkdirs(zone_dst_dir)
dbutils.fs.cp(zone_src, f"{zone_dst_dir}/taxi_zone_lookup.csv", recurse=False)

zones = (spark.read
         .option("header", True)
         .csv(f"{zone_dst_dir}/taxi_zone_lookup.csv")
         .select(F.col("LocationID").cast("int").alias("LocationID"),
                 "Borough", "Zone"))

from pyspark.sql.functions import broadcast
zones_b = broadcast(zones)

with_zones = (fhvhv_tr
    .join(zones_b.withColumnRenamed("LocationID","PU"), F.col("PULocationID")==F.col("PU"), "left")
    .withColumnRenamed("Borough","PU_Borough").withColumnRenamed("Zone","PU_Zone")
    .join(zones_b.withColumnRenamed("LocationID","DO"), F.col("DOLocationID")==F.col("DO"), "left")
    .withColumnRenamed("Borough","DO_Borough").withColumnRenamed("Zone","DO_Zone")
)

# Example aggregation using joined columns
top_borough = (with_zones
    .groupBy("PU_Borough")
    .agg(F.sum("revenue").alias("rev"), F.count("*").alias("trips"))
    .orderBy(F.desc("rev")))

# Write + plan
out_dir = "/Volumes/main/default/nyc_fhvhv_out"
(top_borough.coalesce(1).write.mode("overwrite").parquet(f"{out_dir}/top_borough"))

print("\n==== EXPLAIN: top_borough (with broadcast joins) ====\n")
top_borough.explain(mode="formatted")
# Out:
# ==== EXPLAIN: top_borough (with broadcast joins) ====
#
# == Physical Plan ==
# AdaptiveSparkPlan (32)
# +- == Initial Plan ==
#    ColumnarToRow (31)
#    +- PhotonResultStage (30)
#       +- PhotonSort (29)
#          +- PhotonShuffleExchangeSource (28)
#             +- PhotonShuffleMapStage (27)
#                +- PhotonShuffleExchangeSink (26)
#                   +- PhotonGroupingAgg (25)
#                      +- PhotonShuffleExchangeSource (24)
#                         +- PhotonShuffleMapStage (23)
#                            +- PhotonShuffleExchangeSink (22)
#                               +- PhotonGroupingAgg (21)
#                                  +- PhotonProject (20)
#                                     +- PhotonBroadcastHashJoin LeftOuter (19)
#                                        :- PhotonProject (11)
#                                        :  +- PhotonBroadcastHashJoin LeftOuter (10)
#                                        :     :- PhotonProject (2)
#                                        :     :  +- PhotonScan parquet  (1)
#                                        :     +- PhotonShuffleExchangeSource (9)
#                                        :        +- PhotonShuffleMapStage (8)
#                                        :           +- PhotonShuffleExchangeSink (7)
#                                        :              +- PhotonProject (6)
#                                        :                 +- PhotonFilter (5)
#                                        :                    +- PhotonRowToColumnar (4)
#                                        :                       +- Scan csv  (3)
#                                        +- PhotonShuffleExchangeSource (18)
#                                           +- PhotonShuffleMapStage (17)
#                                              +- PhotonShuffleExchangeSink (16)
#                                                 +- PhotonProject (15)
#                                                    +- PhotonFilter (14)
#                                                       +- PhotonRowToColumnar (13)
#                                                          +- Scan csv  (12)
#
#
# (1) PhotonScan parquet
# Output [12]: [PULocationID#11317, DOLocationID#11318, trip_miles#11319, trip_time#11320L, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334]
# DictionaryFilters: [(trip_time#11320L > 0), (trip_miles#11319 > 0.0)]
# Location: InMemoryFileIndex [dbfs:/Volumes/main/default/nyc_fhvhv/fhvhv_tripdata_2025-01.parquet, ... 2 entries]
# ReadSchema: struct<PULocationID:int,DOLocationID:int,trip_miles:double,trip_time:bigint,base_passenger_fare:double,tolls:double,bcf:double,sales_tax:double,congestion_surcharge:double,airport_fee:double,tips:double,cbd_congestion_fee:double>
# RequiredDataFilters: [isnotnull(PULocationID#11317), isnotnull(DOLocationID#11318), isnotnull(trip_miles#11319), isnotnull(trip_time#11320L), (trip_miles#11319 > 0.0), (trip_time#11320L > 0), CASE WHEN ((cast(trip_time#11320L as double) / 60.0) > 0.0) THEN ((trip_miles#11319 / ((cast(trip_time#11320L as double) / 60.0) / 60.0)) >= 1.0) END, CASE WHEN ((cast(trip_time#11320L as double) / 60.0) > 0.0) THEN ((trip_miles#11319 / ((cast(trip_time#11320L as double) / 60.0) / 60.0)) <= 90.0) END]
#
# (2) PhotonProject
# Input [12]: [PULocationID#11317, DOLocationID#11318, trip_miles#11319, trip_time#11320L, base_passenger_fare#11321, tolls#11322, bcf#11323, sales_tax#11324, congestion_surcharge#11325, airport_fee#11326, tips#11327, cbd_congestion_fee#11334]
# Arguments: [PULocationID#11317, DOLocationID#11318, (((((((coalesce(base_passenger_fare#11321, 0.0) + coalesce(tolls#11322, 0.0)) + coalesce(tips#11327, 0.0)) + coalesce(bcf#11323, 0.0)) + coalesce(sales_tax#11324, 0.0)) + coalesce(congestion_surcharge#11325, 0.0)) + coalesce(airport_fee#11326, 0.0)) + coalesce(cbd_congestion_fee#11334, 0.0)) AS revenue#11367]
#
# (3) Scan csv
# Output [2]: [LocationID#11990, Borough#11991]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/Volumes/main/default/nyc_fhvhv_out/lookup/taxi_zone_lookup.csv]
# PushedFilters: [IsNotNull(LocationID)]
# ReadSchema: struct<LocationID:string,Borough:string>
#
# (4) PhotonRowToColumnar
# Input [2]: [LocationID#11990, Borough#11991]
#
# (5) PhotonFilter
# Input [2]: [LocationID#11990, Borough#11991]
# Arguments: (isnotnull(LocationID#11990) AND isnotnull(cast(LocationID#11990 as int)))
#
# (6) PhotonProject
# Input [2]: [LocationID#11990, Borough#11991]
# Arguments: [cast(LocationID#11990 as int) AS PU#12077, Borough#11991]
#
# (7) PhotonShuffleExchangeSink
# Input [2]: [PU#12077, Borough#11991]
# Arguments: SinglePartition
#
# (8) PhotonShuffleMapStage
# Input [2]: [PU#12077, Borough#11991]
# Arguments: EXECUTOR_BROADCAST, [id=#10435]
#
# (9) PhotonShuffleExchangeSource
# Input [2]: [PU#12077, Borough#11991]
#
# (10) PhotonBroadcastHashJoin
# Left keys [1]: [PULocationID#11317]
# Right keys [1]: [PU#12077]
# Join type: LeftOuter
# Join condition: None
#
# (11) PhotonProject
# Input [5]: [PULocationID#11317, DOLocationID#11318, revenue#11367, PU#12077, Borough#11991]
# Arguments: [DOLocationID#11318, revenue#11367, Borough#11991 AS PU_Borough#12078]
#
# (12) Scan csv
# Output [1]: [LocationID#12082]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/Volumes/main/default/nyc_fhvhv_out/lookup/taxi_zone_lookup.csv]
# PushedFilters: [IsNotNull(LocationID)]
# ReadSchema: struct<LocationID:string>
#
# (13) PhotonRowToColumnar
# Input [1]: [LocationID#12082]
#
# (14) PhotonFilter
# Input [1]: [LocationID#12082]
# Arguments: (isnotnull(LocationID#12082) AND isnotnull(cast(LocationID#12082 as int)))
#
# (15) PhotonProject
# Input [1]: [LocationID#12082]
# Arguments: [cast(LocationID#12082 as int) AS DO#12081]
#
# (16) PhotonShuffleExchangeSink
# Input [1]: [DO#12081]
# Arguments: SinglePartition
#
# (17) PhotonShuffleMapStage
# Input [1]: [DO#12081]
# Arguments: EXECUTOR_BROADCAST, [id=#10448]
#
# (18) PhotonShuffleExchangeSource
# Input [1]: [DO#12081]
#
# (19) PhotonBroadcastHashJoin
# Left keys [1]: [DOLocationID#11318]
# Right keys [1]: [DO#12081]
# Join type: LeftOuter
# Join condition: None
#
# (20) PhotonProject
# Input [4]: [DOLocationID#11318, revenue#11367, PU_Borough#12078, DO#12081]
# Arguments: [revenue#11367, PU_Borough#12078]
#
# (21) PhotonGroupingAgg
# Input [2]: [revenue#11367, PU_Borough#12078]
# Arguments: [PU_Borough#12078], [partial_sum(revenue#11367) AS sum#12094, partial_count(1) AS count#12096L], [sum#12093, count#12095L], [PU_Borough#12078, sum#12094, count#12096L], false
#
# (22) PhotonShuffleExchangeSink
# Input [3]: [PU_Borough#12078, sum#12094, count#12096L]
# Arguments: hashpartitioning(PU_Borough#12078, 200)
#
# (23) PhotonShuffleMapStage
# Input [3]: [PU_Borough#12078, sum#12094, count#12096L]
# Arguments: ENSURE_REQUIREMENTS, [id=#10457]
#
# (24) PhotonShuffleExchangeSource
# Input [3]: [PU_Borough#12078, sum#12094, count#12096L]
#
# (25) PhotonGroupingAgg
# Input [3]: [PU_Borough#12078, sum#12094, count#12096L]
# Arguments: [PU_Borough#12078], [finalmerge_sum(merge sum#12094) AS sum(revenue)#12092, finalmerge_count(merge count#12096L) AS count(1)#12091L], [sum(revenue)#12092, count(1)#12091L], [PU_Borough#12078, sum(revenue)#12092 AS rev#12089, count(1)#12091L AS trips#12090L], true
#
# (26) PhotonShuffleExchangeSink
# Input [3]: [PU_Borough#12078, rev#12089, trips#12090L]
# Arguments: rangepartitioning(rev#12089 DESC NULLS LAST, 200)
#
# (27) PhotonShuffleMapStage
# Input [3]: [PU_Borough#12078, rev#12089, trips#12090L]
# Arguments: ENSURE_REQUIREMENTS, [id=#10463]
#
# (28) PhotonShuffleExchangeSource
# Input [3]: [PU_Borough#12078, rev#12089, trips#12090L]
#
# (29) PhotonSort
# Input [3]: [PU_Borough#12078, rev#12089, trips#12090L]
# Arguments: [rev#12089 DESC NULLS LAST]
#
# (30) PhotonResultStage
# Input [3]: [PU_Borough#12078, rev#12089, trips#12090L]
#
# (31) ColumnarToRow
# Input [3]: [PU_Borough#12078, rev#12089, trips#12090L]
#
# (32) AdaptiveSparkPlan
# Output [3]: [PU_Borough#12078, rev#12089, trips#12090L]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
# Transformations (lazy)
lazy_df = with_zones.filter((F.col("year")==2025) & (F.col("month")==1)).select("pickup_ts","revenue")

# Action (eager) triggers execution
print("Actions vs Transformations — count():", lazy_df.count())
# Out:
# Actions vs Transformations — count(): 20400288
